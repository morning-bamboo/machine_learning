# %% [markdown]
# # Imbalanced dataset
#
#
#
#
# ![Lesson37-dealing imbalance data.png](attachment:dd3f793f-2353-4c8f-8677-293e987f3ca9.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
import warnings
warnings.filterwarnings("ignore")

from sklearn.svm import OneClassSVM
from pylab import rcParams
from sklearn.metrics import precision_score
rcParams["figure.figsize"] = 14,8
RANDOM_SEED = 42
LABELS = ["Normal","Fraud"]

# %%
url = r"Downloads\RC37_creditcard.csv"
data = pd.read_csv(url, sep=",")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
Y = data["Class"]
X = data.iloc[:,:-1]
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.isna().values.any()
# Out:
# np.False_

# %%
count_classes = data["Class"]
count_classes.value_counts()

# sns.countplot(count_classes.)
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
count_classes = pd.value_counts(data["Class"],sort=True)
count_classes

count_classes.plot(kind = 'bar', rot=0)

plt.title("Transaction Class Distribution")

plt.xticks(range(2), LABELS)

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fraud = data[data.Class ==1]
normal = data[data.Class ==0]
fraud.shape
# Out:
# (492, 31)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 99.94%

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[85292,    16],
#        [   35,   100]])

# %%
precision_score(y_test,y_pred)
# Out:
# 0.8620689655172413

# %% [markdown]
# ### the precision_score is not very high - so more processing required to get best fit

# %% [markdown]
# # 1 Undersamping

# %% [markdown]
# ## (1.1) under_sampling NearMiss

# %%
from imblearn.under_sampling import NearMiss


# Implementing Undersampling for Handling Imbalanced 
#nm = NearMiss(random_state=42)
nm = NearMiss() # This uses the default parameters
X_res,y_res= nm.fit_resample(X,Y)

# %%
X_res.shape,y_res.shape
# Out:
# ((984, 30), (984,))

# %%
from collections import Counter

Counter(Y)
# Out:
# Counter({0: 284315, 1: 492})

# %%
Counter(y_res)
# Out:
# Counter({0: 492, 1: 492})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=1)

model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 95.61%

# %%
confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[140,   2],
#        [ 11, 143]])

# %%
precision_score(y_test, y_pred)
# Out:
# 0.9862068965517241

# %% [markdown]
# ## (1.2) under_sampling RandomUnderSampler

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=0)
rus.fit(X, Y)
X_res, y_res = rus.fit_resample(X, Y)

# %%
X_res.shape,y_res.shape
# Out:
# ((984, 30), (984,))

# %%
Counter(Y),Counter(y_res)
# Out:
# (Counter({0: 284315, 1: 492}), Counter({0: 492, 1: 492}))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=1)

model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 94.93%

# %%
confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[139,   3],
#        [ 12, 142]])

# %%
precision_score(y_test, y_pred)
# Out:
# 0.9793103448275862

# %% [raw]
# under_sampling (down sampling)
# Advantages
# It can help improve run time and storage problems by reducing the number of training data samples when the training data set is huge.
#
# Disadvantages
# It can discard potentially useful information which could be important for building rule classifiers. The sample chosen by random under sampling may be a biased sample. And it will not be an accurate representative of the population. Thereby, resulting in inaccurate results with the actual test data set.

# %% [markdown]
# # 2 Oversamping

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")

from sklearn.svm import OneClassSVM
from pylab import rcParams
from sklearn.metrics import precision_score
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
url = r"Downloads\RC37_creditcard.csv"
data = pd.read_csv(url, sep=",")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
Y = data['Class']
X = data.drop('Class',axis=1,inplace=False)

# %%
from imblearn.combine import SMOTETomek

# Implementing Oversampling for Handling Imbalanced 
smk = SMOTETomek(random_state=42,n_jobs=-1)
X_res,y_res=smk.fit_resample(X,Y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=1)

model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# SMOTETomek()

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 94.93%

# %%
confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[139,   3],
#        [ 12, 142]])

# %%
precision_score(y_test, y_pred)
# Out:
# 0.9793103448275862

# %% [markdown]
# ## (2.2) over_sampling RandomOverSampler

# %%
from imblearn.over_sampling import RandomOverSampler

ros =  RandomOverSampler(random_state=10)

X_res, y_res = ros.fit_resample(X, Y)

# %%
X_res.shape,y_res.shape
# Out:
# ((568630, 30), (568630,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=1)

model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 99.99%

# %%
confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[85412,    16],
#        [    0, 85161]])

# %%
precision_score(y_test, y_pred)
# Out:
# 0.9998121558636721

# %% [raw]
# over_sampling
#
# Advantages
# Unlike under sampling this method leads to no information loss. Outperforms under sampling
#
# Disadvantages
# It increases the likelihood of overfitting since it replicates the minority class events.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix(y_true=y_test, y_pred=y_pred), display_labels=model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ## (3+) others methods： LogisticRegression, Tree-Based Algorithms, support vector machine (SVC),neural network ...
