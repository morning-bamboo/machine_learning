# %% [markdown]
# # Neural network model
#
# ![Lesson46-01.png](attachment:84f5beae-a2da-485a-86c4-6c08af42b956.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
a,b = np.arange(3),np.arange(3,6)
a
# Out:
# array([0, 1, 2])

# %%
b
# Out:
# array([3, 4, 5])

# %%
np.dot(a,b)
# Out:
# np.int64(14)

# %%
a@b
# Out:
# np.int64(14)

# %%
c,d = np.arange(4).reshape(2,2),np.arange(3,9).reshape(2,3)

# %%
np.dot(c,d)
# Out:
# array([[ 6,  7,  8],
#        [24, 29, 34]])

# %%
x=[1,2,3]
w = [0.7,0.6,1.4]
bias = 1

# %%
np.dot(x,w)+bias
# Out:
# np.float64(7.1)

# %% [markdown]
# ## one-layer Neuron Network

# %%
import numpy as np 
def sigmoid(x):
    return 1/(1+np.exp(-x))

class Neuron:
    def __init__(self,weights,bias):
        self.weights=weights
        self.bias = bias

    def feedforward(self,inputs):
        total = np.dot(inputs,weights) + self.bias

        return sigmoid(total)

weights = np.array([0.7,0.6,1.4])
bias = 1
n = Neuron(weights,bias)

x = np.array([1,2,3])
n.feedforward(x)
# Out:
# np.float64(0.9991755753136017)

# %% [markdown]
# ## two-layer/one-hidden-layer Neuron Network

# %%
import numpy as np

def sigmoid(x):
    return 1/(1+np.exp(-x))

class Neuron:
    def __init__(self,weights,bias):
        self.weights=weights
        self.bias = bias

    def feedforward(self,inputs):
        total = np.dot(inputs,weights) + self.bias

        return sigmoid(total)

class OurNeuralNetwork:
    """ 
    a neural network with;
    3 inputs
    1 hidden layer with 3 neurons (h1,h2,h3)
    1 output layer with 1 neurons (o1)
    each neuron has the same weights and bias:
    w = [0.7,0.6,1.4]
    bias=1
    """ 
    def __init__(self):
        weights = np.array([0.7,0.6,1.4])
        bias = 1

        self.h1 = Neuron(weights,bias)
        self.h2 = Neuron(weights,bias)
        self.h3 = Neuron(weights,bias)
        self.o1 = Neuron(weights,bias)
    def feedforward(self,x):
        out_h1 = self.h1.feedforward(x)
        out_h2 = self.h2.feedforward(x)
        out_h3 = self.h3.feedforward(x)

        out_o1 = self.o1.feedforward(np.array([out_h1,out_h2,out_h3]))

        return out_o1

network = OurNeuralNetwork()
x = np.array([1,2,3])
network.feedforward(x)
# Out:
# np.float64(0.9758205133194947)
